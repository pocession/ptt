# %%
# Get article information from database
# Get contents of each article from ptt 
# Process contents into a list of sentences
# Read sentences based on "，", not " " or "\n"
# Break sentences in words
# Then remove stop words
# Pool all this sentences in a list
# Save processed word list into database

import re
import jieba
import sqlite3
import requests
import csv
from bs4 import BeautifulSoup


def sentence_check(a):
    # The faster way is creating a list, then checking any unwanted characters before replacing it. 
    # However, this way produces multiple output, which increase some complexity 
    print("run sentence check")
    element=a
    temp_list=[]
    return_list=[]
    pattern = r',|\.|/|;|\'|`|\[|\]|<|>|\?|:|"|\{|\}|\~|!|@|#|\$|%|\^|&|\(|\)|-|=|\_|\+|，|。|、|；|‘|’|【|】|·|！| |…|（|）' 
    
    element = re.split(pattern,element)
    for t in element:
        if t != '':
            temp_list.append(t)
    
    # Remove \n in list
    temp_list = [x for x in temp_list if x != '\n']
    for item in temp_list:
        item = item.replace("\n","")
        return_list.append(item)
    return(return_list)

# Read sentences of an article and process them as a bag of words
# Use jieba module to recognize chinese words
# Need a dictionary of common tradition Chinese words
# Need a dictionary of stop words
# Return a list of lists of words (still keep the sentence information)
def word(a):
    print("Run word, powered by JieBa")
    input_list = a
    jieba.set_dictionary('dict.txt')
    stops = open('stop.txt', 'r', encoding='utf8') 
    stopword = stops.read().split('\n')
    stops.close()
    
    # Update stop words
    stopword.append('\n')
    stopword.append(" ")
    stopword.append("")
    
    new_list=[]
    i = 0
    
    # Remove any stop words from list
    while i < len(input_list):
        element = input_list[i]
        new_list.append([t for t in jieba.cut(element) if t not in stopword])
        i+=1
    
    return(new_list)


# Enter the subforum which you want to scrape data from
# Subforum name is case sensitive

def main():
    conn = sqlite3.connect('ptt.db')
    c = conn.cursor()
    cursor = c.execute("SELECT id from test")
    articleid_list=[]
    for row in cursor:
        articleid_list.append(row[0])
    cursor.close()

    name = input("Enter which sub forum you want to scrape data from: ")
    print("get data from {a}".format(a = name))

    # Send http request to server
    text_list=[]
    for element in articleid_list:
        url = "https://www.ptt.cc/bbs/{name}/".format(name=name)
        url= url+element
        response = requests.get(url, cookies={'over18': '1'}) 
        result = response.text
        soup = BeautifulSoup(result, 'html.parser')
        soup = soup.find(id="main-content")
        for span in soup('span'):
            span.decompose()
        for div in soup('div'):
            div.decompose()
        for a in soup('a'):
            a.decompose()
        text_list.append(soup.text)


       # Get clean sentence from each article
        sentence_list=[]
        for element in text_list:
            a = sentence_check(element)
            sentence_list.append(a)

        # Get a bag of words from each article
        word_list=[]
        for element in sentence_list:
            a = word(element)
            word_list.append(a)
        print(word_list)
        
        
if __name__ == "__main__":
    print("initialize")
    main()
# Out:
# initialize
# Enter which sub forum you want to scrape data from: Japan_Travel
# get data from Japan_Travel
# Building prefix dict from /Users/hsieh/Documents/ptt/dict.txt ...
# Loading model from cache /var/folders/54/w85qh3vd4xv5v6qz8w4t70940000gn/T/jieba.ubaa545e936adb4bd7ef290058a1bf422.cache
# run sentence check
# Run word, powered by JieBa
# Loading model cost 0.769 seconds.
# Prefix dict has been built succesfully.
# [[['2月', '時', '開一', '團帶', '同事', '北九州'], ['過程', '中', '報名', '人數', '不斷', '增加'], ['最後', '變成', '14', '小的團'], ['第一次', '帶團'], ['先前', 'PO', '文', '詢問', '時'], ['網友', '推文', '說', '一定', '吵架'], ['記得', '回報', '想', '說'], ['吵架'], ['真的', '完全', '吵架'], ['心胸', '開闊'], ['哪有', '好', '吵'], ['看到', '前', '陣子', '分享', '孝親', '之旅'], ['裏頭'], ['父母'], ['那還', '真的', '沒把握'], ['XDD', '運氣'], ['真該', '慶幸', '同事', '好', '相處', '人'], [], ['前言', '結束'], ['囉嗦', '遊記'], ['直接', '重點', '整理好'], [], ['20'], [], ['虎航', '0645'], ['1000', '福岡'], ['機場', '巴士', '博多', '站換', '北九州', '三日', '鐵路', '周遊券'], ['劃位'], ['此時', '介紹', '吃', '半熟', '咖哩', '蛋', '麵包'], ['可頌'], ['避免', '無聊'], ['搭地鐵', '前往', '中洲', '川端'], ['介紹', '飯店', '最近', '唐吉軻德', '一蘭', '本店', '位址'], ['西鐵', 'INN'], ['福岡'], ['放', '行李'], ['步行', '天神'], ['午餐', '吃', '純情', '拉麵', '本店'], ['同意', '排隊', '吃', '囉'], ['獲', '好評'], ['自由', '行動', '亂逛'], ['認識', '環境', '優先'], ['部分', '人', '晚餐'], ['博多'], ['祇園'], ['鉄', 'な', 'べ'], ['請客', 'soso'], ['日本', '沒吃過', '滿意', '煎餃'], ['回程', '唐吉軻德', '買酒', '續攤'], ['21'], [], ['飯店', '對面', 'Acros', '福岡', '地下', '通道', '前往', '天神'], ['每次', '帶路', '走不同', '路線'], ['希望', '盡快', '熟悉', '環境'], ['排隊', '購買', '福岡', 'City'], ['PASS', '太宰', '府', '版'], ['感覺', '得出', '買', '票券', '這種', '行為', '感到', '新奇'], ['前往', '太宰', '府'], ['自由', '行動'], ['包括', '回程', '需求'], ['Outlet', '組'], ['姪', '浜', '駅', '會合', '搭', '昭和', '巴士', '前往', '瑪莉', '諾雅'], ['先', '約定', '晚上', '點', '30', '分', '會合', '一起', '吃', '燒肉', '吃到飽'], ['每人', '逛', 'Outlet', '時間'], ['回到', '飯店'], ['一組', '母女', '沒想', '買'], ['只好', '先', '早早', '結束', '回去'], ['前往', 'ワ', 'ン', 'カ', 'ル', 'ビ', 'PREMIUM', '中洲'], ['排隊', '改搭', '地鐵', '博多', '站', 'Yodobashi', '四樓', '牛太本陣'], ['順便', '介紹', '樓', '玩具', '扭蛋', '牆'], ['續攤', '喝酒'], ['22'], [], ['使用', '鐵路', '三日券', '1024', '前往', '布院'], ['帶著', '行李', '跑'], ['土產店', '放', '行李'], ['件', '500'], ['後續', '300'], ['自由', '行動'], ['前往'], ['由布', 'ま', 'ぶ', 'し'], ['心'], ['金鱗', '湖本', '店'], ['1651', '搭車', '前往', '大分'], ['再', '轉車', '別府'], ['飯店', '放', '行李'], ['自由', '行動'], ['先', '推薦', '晚餐', '可吃炸', '蝦', '天婦羅'], ['と', 'よ', '常本店'], ['23'], [], ['悠閒', '出發', '搭', '音速號', '前往', '小倉'], ['旦過', '市場', '附近', '飯店', '放', '行李'], ['部分', '人', '午餐', '大學', '丼'], ['小倉城'], ['商店街', '散步'], ['1600', '搭車', '前往', '八幡', '站'], ['再', '搭', '接駁', '巴士', '往皿', '倉山', '纜車'], ['搭', '1855', '纜車', '下山', '回程'], ['小倉', '站', '吃', '利久', '牛舌'], ['主管', '請客'], ['自由', '行動'], ['部分', '人', '飯店', '交誼廳', '喝酒', '談心'], ['24'], ['日'], ['共識', '早', '出發', '早點', '回到', '博多'], ['門司', '港'], ['搭', '渡輪', '唐戶', '市場'], ['搭個', '船', '感覺', '行程', '多元', '豐富'], ['回', '小倉'], ['搭', '高架', '單軌', '電車', '回飯店', '行李'], ['博多', '飯店', '放完', '行李', '自由', '行動'], ['一組', '搭', '新幹線', '前往', '熊本'], ['25'], [], ['香草', '返台'], [], ['20'], [], ['21'], ['西鐵', 'INN'], ['福岡'], ['位於', '中洲', '天神', '間'], ['評估', '適合', '自由', '行動', '起點'], [], ['22'], ['別府', '新鶴田', '飯店'], ['增加', '一間', '日式', '塌塌米'], ['溫泉', '體驗'], ['房價', '便宜'], ['房間', '特大'], ['早餐'], [], ['23'], ['小倉'], [], [], ['週六', '飯店', '下', '選擇'], ['房價', '便宜'], ['整體', '環境', '差'], ['飯店', '樓有', '小門接', '全家'], ['餐廳', '交誼廳'], ['喝酒', '聊天', '超級', '方便'], [], ['24'], ['博多', '八百治'], ['最後', '一晚', '想要', '溫泉', '選擇'], ['房價', '便宜'], ['房間', '出乎意料', '乾淨', '明亮'], ['CP', '值', '意外', '地高'], ['總共', '天', '夜'], ['實際', '跑行程', '時'], ['以外'], ['人有', '帶路', '能力'], ['這讓', '整體', '自由度', '高'], ['不用', '綁', '一起'], ['我想', '事前', '準備'], ['這次', '行程', '能夠', '順利', '主因'], [], ['部', '分', '相片'], ['西鐵', 'INN'], ['福岡', '房間', '運河', '景', '博多', '運河', '城'], ['哥吉拉', '燈光秀', '新鶴田', '飯店', '洋房'], ['照片', '約', '房間', '一半'], ['兩張', '單人床', '浴室'], ['別府'], ['と', 'よ', '常本店'], ['隻', '蝦'], ['皿', '倉山', '白天', '景'], ['有夠', '冷'], ['覺得', '長崎', '稻佐山', '好'], ['皿', '倉山', '夜景'], ['可惜', '黃昏', '階段'], ['熊本城', '現況', '最後', '一天', '一個', '人', '吃', '新', '三浦'], ['水', '炊鍋'], ['沒住', '大分'], ['別府', '住宿', '新鶴田', '溫泉', '飯店'], ['含', '早餐'], ['規劃', '確實', '預算', '考量'], ['沒辦法'], ['想', '盡量', '幫', '省錢'], ['想', '吃', '炸', '蝦', '天婦羅', '明白', '意思'], ['謝謝', '提醒'], ['指', '想', '提前', '回到', '博多', '自由', '行動'], ['同意', '早點', '出發'], ['早點', '結束', '門司', '港'], ['唐戶', '行程', '意思', '下', '飛機', '後', '先到', '博多', '站', '喔'], ['0924', '已經'], ['改成', '1024', '班次'], ['行程', '排得', '緊'], ['一人', '花個', ...
# Building prefix dict from /Users/hsieh/Documents/ptt/dict.txt ...
# Loading model from cache /var/folders/54/w85qh3vd4xv5v6qz8w4t70940000gn/T/jieba.ubaa545e936adb4bd7ef290058a1bf422.cache
# run sentence check
# run sentence check
# Run word, powered by JieBa
# Loading model cost 0.877 seconds.
# Prefix dict has been built succesfully.
# Building prefix dict from /Users/hsieh/Documents/ptt/dict.txt ...
# Loading model from cache /var/folders/54/w85qh3vd4xv5v6qz8w4t70940000gn/T/jieba.ubaa545e936adb4bd7ef290058a1bf422.cache
# Run word, powered by JieBa
# Loading model cost 0.902 seconds.
# Prefix dict has been built succesfully.
# [[['2月', '時', '開一', '團帶', '同事', '北九州'], ['過程', '中', '報名', '人數', '不斷', '增加'], ['最後', '變成', '14', '小的團'], ['第一次', '帶團'], ['先前', 'PO', '文', '詢問', '時'], ['網友', '推文', '說', '一定', '吵架'], ['記得', '回報', '想', '說'], ['吵架'], ['真的', '完全', '吵架'], ['心胸', '開闊'], ['哪有', '好', '吵'], ['看到', '前', '陣子', '分享', '孝親', '之旅'], ['裏頭'], ['父母'], ['那還', '真的', '沒把握'], ['XDD', '運氣'], ['真該', '慶幸', '同事', '好', '相處', '人'], [], ['前言', '結束'], ['囉嗦', '遊記'], ['直接', '重點', '整理好'], [], ['20'], [], ['虎航', '0645'], ['1000', '福岡'], ['機場', '巴士', '博多', '站換', '北九州', '三日', '鐵路', '周遊券'], ['劃位'], ['此時', '介紹', '吃', '半熟', '咖哩', '蛋', '麵包'], ['可頌'], ['避免', '無聊'], ['搭地鐵', '前往', '中洲', '川端'], ['介紹', '飯店', '最近', '唐吉軻德', '一蘭', '本店', '位址'], ['西鐵', 'INN'], ['福岡'], ['放', '行李'], ['步行', '天神'], ['午餐', '吃', '純情', '拉麵', '本店'], ['同意', '排隊', '吃', '囉'], ['獲', '好評'], ['自由', '行動', '亂逛'], ['認識', '環境', '優先'], ['部分', '人', '晚餐'], ['博多'], ['祇園'], ['鉄', 'な', 'べ'], ['請客', 'soso'], ['日本', '沒吃過', '滿意', '煎餃'], ['回程', '唐吉軻德', '買酒', '續攤'], ['21'], [], ['飯店', '對面', 'Acros', '福岡', '地下', '通道', '前往', '天神'], ['每次', '帶路', '走不同', '路線'], ['希望', '盡快', '熟悉', '環境'], ['排隊', '購買', '福岡', 'City'], ['PASS', '太宰', '府', '版'], ['感覺', '得出', '買', '票券', '這種', '行為', '感到', '新奇'], ['前往', '太宰', '府'], ['自由', '行動'], ['包括', '回程', '需求'], ['Outlet', '組'], ['姪', '浜', '駅', '會合', '搭', '昭和', '巴士', '前往', '瑪莉', '諾雅'], ['先', '約定', '晚上', '點', '30', '分', '會合', '一起', '吃', '燒肉', '吃到飽'], ['每人', '逛', 'Outlet', '時間'], ['回到', '飯店'], ['一組', '母女', '沒想', '買'], ['只好', '先', '早早', '結束', '回去'], ['前往', 'ワ', 'ン', 'カ', 'ル', 'ビ', 'PREMIUM', '中洲'], ['排隊', '改搭', '地鐵', '博多', '站', 'Yodobashi', '四樓', '牛太本陣'], ['順便', '介紹', '樓', '玩具', '扭蛋', '牆'], ['續攤', '喝酒'], ['22'], [], ['使用', '鐵路', '三日券', '1024', '前往', '布院'], ['帶著', '行李', '跑'], ['土產店', '放', '行李'], ['件', '500'], ['後續', '300'], ['自由', '行動'], ['前往'], ['由布', 'ま', 'ぶ', 'し'], ['心'], ['金鱗', '湖本', '店'], ['1651', '搭車', '前往', '大分'], ['再', '轉車', '別府'], ['飯店', '放', '行李'], ['自由', '行動'], ['先', '推薦', '晚餐', '可吃炸', '蝦', '天婦羅'], ['と', 'よ', '常本店'], ['23'], [], ['悠閒', '出發', '搭', '音速號', '前往', '小倉'], ['旦過', '市場', '附近', '飯店', '放', '行李'], ['部分', '人', '午餐', '大學', '丼'], ['小倉城'], ['商店街', '散步'], ['1600', '搭車', '前往', '八幡', '站'], ['再', '搭', '接駁', '巴士', '往皿', '倉山', '纜車'], ['搭', '1855', '纜車', '下山', '回程'], ['小倉', '站', '吃', '利久', '牛舌'], ['主管', '請客'], ['自由', '行動'], ['部分', '人', '飯店', '交誼廳', '喝酒', '談心'], ['24'], ['日'], ['共識', '早', '出發', '早點', '回到', '博多'], ['門司', '港'], ['搭', '渡輪', '唐戶', '市場'], ['搭個', '船', '感覺', '行程', '多元', '豐富'], ['回', '小倉'], ['搭', '高架', '單軌', '電車', '回飯店', '行李'], ['博多', '飯店', '放完', '行李', '自由', '行動'], ['一組', '搭', '新幹線', '前往', '熊本'], ['25'], [], ['香草', '返台'], [], ['20'], [], ['21'], ['西鐵', 'INN'], ['福岡'], ['位於', '中洲', '天神', '間'], ['評估', '適合', '自由', '行動', '起點'], [], ['22'], ['別府', '新鶴田', '飯店'], ['增加', '一間', '日式', '塌塌米'], ['溫泉', '體驗'], ['房價', '便宜'], ['房間', '特大'], ['早餐'], [], ['23'], ['小倉'], [], [], ['週六', '飯店', '下', '選擇'], ['房價', '便宜'], ['整體', '環境', '差'], ['飯店', '樓有', '小門接', '全家'], ['餐廳', '交誼廳'], ['喝酒', '聊天', '超級', '方便'], [], ['24'], ['博多', '八百治'], ['最後', '一晚', '想要', '溫泉', '選擇'], ['房價', '便宜'], ['房間', '出乎意料', '乾淨', '明亮'], ['CP', '值', '意外', '地高'], ['總共', '天', '夜'], ['實際', '跑行程', '時'], ['以外'], ['人有', '帶路', '能力'], ['這讓', '整體', '自由度', '高'], ['不用', '綁', '一起'], ['我想', '事前', '準備'], ['這次', '行程', '能夠', '順利', '主因'], [], ['部', '分', '相片'], ['西鐵', 'INN'], ['福岡', '房間', '運河', '景', '博多', '運河', '城'], ['哥吉拉', '燈光秀', '新鶴田', '飯店', '洋房'], ['照片', '約', '房間', '一半'], ['兩張', '單人床', '浴室'], ['別府'], ['と', 'よ', '常本店'], ['隻', '蝦'], ['皿', '倉山', '白天', '景'], ['有夠', '冷'], ['覺得', '長崎', '稻佐山', '好'], ['皿', '倉山', '夜景'], ['可惜', '黃昏', '階段'], ['熊本城', '現況', '最後', '一天', '一個', '人', '吃', '新', '三浦'], ['水', '炊鍋'], ['沒住', '大分'], ['別府', '住宿', '新鶴田', '溫泉', '飯店'], ['含', '早餐'], ['規劃', '確實', '預算', '考量'], ['沒辦法'], ['想', '盡量', '幫', '省錢'], ['想', '吃', '炸', '蝦', '天婦羅', '明白', '意思'], ['謝謝', '提醒'], ['指', '想', '提前', '回到', '博多', '自由', '行動'], ['同意', '早點', '出發'], ['早點', '結束', '門司', '港'], ['唐戶', '行程', '意思', '下', '飛機', '後', '先到', '博多', '站', '喔'], ['0924', '已經'], ['改成', '1024', '班次'], ['行程', '排得', '緊'], ['一人', '花個', ...
