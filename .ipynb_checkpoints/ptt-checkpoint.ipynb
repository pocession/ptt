# %%
# Some practice for scraping ptt

import requests
from bs4 import BeautifulSoup

name = input("Enter which sub forum you want to scrape data from: ")

url = "https://www.ptt.cc/bbs/"+name+"/index.html"
response = requests.get(url, cookies={'over18': '1'}) 
result = response.text
soup = BeautifulSoup(result, 'html.parser')

# Get all links

all_a = soup.find_all('a')
# Out:
# Enter which sub forum you want to scrape data from: Japan_travel

# %%
# Check how many articles

page_number_a = soup.find_all('a',attrs={'class':'btn wide'})
page_number_a = page_number_a[1]['href']
page_number = page_number_a
page_number = int(page_number.replace("/bbs/Japan_Travel/index","").replace(".html",""))
page_number
# Out:
# 6505

# %%
# Get review counts + title
article_review = soup.find_all('div',attrs={'class':'nrec'})
article_title = soup.find_all('div', attrs={'class':'title'})
print("Total review counts: ",len(article_review))
print("Total article number:",len(article_title))
i = 0
j = 0
while i < len(article_review) and j < len(article_title):
    x = article_review[i].text
    if x == '':
        x = x.replace('','0')
    if x == '爆':
        x = '99'
    x = int(x)
    y = article_title[j]
    print(x,y.text.replace("\n","").replace(" ","").replace("\t",""))
    i+=1
    j+=1
# Out:
# Total review counts:  23
# Total article number: 23
# 0 [遊記]冬季日本北海道輕鬆遊(下)
# 2 [問題]東北關東9天8夜3/29-4/6
# 1 [讓售]東京地鐵24小時兩張期限2019.03.31
# 2 [問題]請問虎航香草航空行李托運問題
# 0 [讓售]東京地鐵24H三張期限2019.9.30（已售）
# 5 [問題]宮島寄物問題
# 2 [問題]原子小金剛icoca購買
# 2 [徵人]3/15大阪環球柯南密室逃脫
# 0 [讓售]東京地鐵24小時
# 3 [問題]關西機場進出的北陸行程
# 4 [資訊]京都東山花燈路2019
# 0 03/01大阪環球柯南密室逃
# 0 [讓售]關西周遊三日券二張
# 0 [徵人]3/9-3/12東京GALA滑雪Teamlab河口湖
# 0 [讓售]東京大江戶溫泉票卷
# 0 [讓售]2019瀨戶內藝術季三季鑑賞護照兌換券
# 0 [讓售]KTP關西周遊卷3日PASS(剩2日）2張
# 0 (本文已被刪除)[s523698]
# 0 [問題]請問富士箱根週遊卷車位問題
# 47 [公告]日本旅遊板板規107.06
# 99 [公告]108.2實況回報(含天氣/物候/穿著詢問)
# 16 [資訊]亞航大阪航線八折/名古屋TWD1539
# 63 [資訊]台灣虎航tigerwow促銷(台灣發、日本發)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 Japan_Travel 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.25/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.25/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.25/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.25/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.25/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/Japan_Travel/index.html"><span class="board-label">看板 </span>Japan_Travel</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/Japan_Travel/index.html">看板</a>
# <a class="btn" href="/man/Japan_Travel/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/Japan_Travel/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/Japan_Travel/index6505.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/Japan_Travel/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Japan_Travel/M.1550894497.A.21E.html">[遊記]  冬季日本北海道輕鬆遊(下)</a>
# </div>
# <div class="meta">
# <div class="author">little96</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Japan_Travel/search?q=thread%3A%5B%E9%81%8A%E8%A8%98%5D++%E5%86%AC%E5%AD%A3%E6%97%A5%E6%9C%AC%E5%8C%97%E6%B5%B7%E9%81%93%E8%BC%95%E9%AC%86%E9%81%8A%28%E4%B8%8B%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Japan_Travel/search?q=author%3
">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Japan_Travel/search?q=author%3Agirlism">搜尋看板內 girlism 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Japan_Travel/M.1550906561.A.8A9.html">[讓售] KTP關西周遊卷3日PASS(剩2日）2張</a>
# </div>
# <div class="meta">
# <div class="author">i12829</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Japan_Travel/search?q=thread%3A%5B%E8%AE%93%E5%94%AE%5D+KTP%E9%97%9C%E8%A5%BF%E5%91%A8%E9%81%8A%E5%8D%B73%E6%97%A5PASS%28%E5%89%A92%E6%97%A5%EF%BC%892%E5%BC%B5">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Japan_Travel/search?q=author%3Ai12829">搜尋看板內 i12829 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
#
# 				(本文已被刪除) [s523698]
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date"> 2/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Japan_Travel/M.1550908361.A.3B2.html">[問題] 請問富士箱根週遊卷車位問題</a>
# </div>
# <div class="meta">
# <div class="author">lonemusic</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Japan_Travel/search?q=thread%3A%5B%E5%95%8F%E9%A1%8C%5D+%E8%AB%8B%E5%95%8F%E5%AF%8C%E5%A3%AB%E7%AE%B1%E6%A0%B9%E9%80%B1%E9%81%8A%E5%8D%B7%E8%BB%8A%E4%BD%8D%E5%95%8F%E9%A1%8C">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Japan_Travel/search?q=author%3Alonemusic">搜尋看板內 lonemusic 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">47</span></div>
# <div class="title">
# <a href="/bbs/Japan_Travel/M.1528480874.A.9E2.html">[公告] 日本旅遊板板規 107.06</a>
# </div>
# <div class="meta">
# <div class="author">neval</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Japan_Travel/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%97%A5%E6%9C%AC%E6%97%85%E9%81%8A%E6%9D%BF%E6%9D%BF%E8%A6%8F+107.06">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Japan_Travel/search?q=author%3Aneval">搜尋看板內 neval 的文章</a></div>
# </div>
# </div>
# <div class="date"> 6/09</div>
# <div class="mark">S</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/Japan_Travel/M.1548977781.A.9DE.html">[公告] 108.2 實況回報(含天氣/物候/穿著詢問)  </a>
# </div>
# <div class="meta">
# <div class="author">sinohara</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Japan_Travel/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+108.2+%E5%AF%A6%E6%B3%81%E5%9B%9E%E5%A0%B1%28%E5%90%AB%E5%A4%A9%E6%B0%A3%2F%E7%89%A9%E5%80%99%2F%E7%A9%BF%E8%91%97%E8%A9%A2%E5%95%8F%29++">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Japan_Travel/search?q=author%3Asinohara">搜尋看板內 sinohara 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/01</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">16</span></div>
# <div class="title">
# <a href="/bbs/Japan_Travel/M.1550491523.A.368.html">[資訊] 亞航大阪航線八折 / 名古屋 TWD1539 </a>
# </div>
# <div class="meta">
# <div class="author">yhls</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Japan_Travel/search?q=thread%3A%5B%E8%B3%87%E8%A8%8A%5D+%E4%BA%9E%E8%88%AA%E5%A4%A7%E9%98%AA%E8%88%AA%E7%B7%9A%E5%85%AB%E6%8A%98+%2F+%E5%90%8D%E5%8F%A4%E5%B1%8B+TWD1539+">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Japan_Travel/search?q=author%3Ayhls">搜尋看板內 yhls 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/18</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">63</span></div>
# <div class="title">
# <a href="/bbs/Japan_Travel/M.1550713270.A.049.html">[資訊] 台灣虎航tigerwow促銷(台灣發、日本發)</a>
# </div>
# <div class="meta">
# <div class="author">OhmoriHarumi</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Japan_Travel/search?q=thread%3A%5B%E8%B3%87%E8%A8%8A%5D+%E5%8F%B0%E7%81%A3%E8%99%8E%E8%88%AAtigerwow%E4%BF%83%E9%8A%B7%28%E5%8F%B0%E7%81%A3%E7%99%BC%E3%80%81%E6%97%A5%E6%9C%AC%E7%99%BC%29">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Japan_Travel/search?q=author%3AOhmoriHarumi">搜尋看板內 OhmoriHarumi 的文章</a></div>
# </div>
# </div>
# <div class="date"> 2/21</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.25/bbs.js"></script>
# </body>
# </html>
